# %% [markdown]
# Ejercicio 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

vehiculos = pd.read_csv(r"vehiculos_700_registros.csv")
pd.set_option('display.max_rows', None)

#--- Info de los veiculos ---

print(vehiculos.head())
print(vehiculos.info())
print(vehiculos.describe())
print(vehiculos.shape)
print(vehiculos.dtypes)

#--- Estadística descriptiva básica ---

# Promedio de ventas
print("PROMEDIO DE LAS VENTAS:")
print(vehiculos["VENTAS_VEHICULO"].mean())

# Ventas mínimo y máximo
print("\nVENTAS MÍNIMO Y MÁXIMO:")
print("Mínimo:", vehiculos["VENTAS_VEHICULO"].min())
print("Máximo:", vehiculos["VENTAS_VEHICULO"].max())

# Precio mínimo y máximo
print("\nPRECIO MÍNIMO Y MÁXIMO:")
print("Mínimo:", vehiculos["PRECIO"].min())
print("Máximo:", vehiculos["PRECIO"].max())

# Desviación estándar de ventas
print("\nDESVIACIÓN STD DE LAS VENTAS:")
print(vehiculos["VENTAS_VEHICULO"].std())

# Desviación estándar del precio
print("\nDESVIACIÓN STD DEL PRECIO:")
print(vehiculos["PRECIO"].std())

# --- Operaciones ---

# Suma total
total_ventas = vehiculos["VENTAS_VEHICULO"].sum()
print(f"\nTotal de ventas: {total_ventas}")

# Conteo de registros
total_registros = vehiculos["ID"].count()
print(f"Total de registros: {total_registros}")

# --- Visualización ---
print("\nPrimeros 5 registros procesados:")
print(vehiculos_sin_nulos.head())

#--- Gráficos ---

# --- Gráficos de barras ---
print("\nGraficas de barras:")
plt.bar(vehiculos["NOMBRE_VEHICULO"],vehiculos["PRECIO"])
plt.title("Precios de los vehiculos")
plt.show()

# --- Histogramas gráicos de líneas ---
plt.hist(vehiculos["PRECIO"])
plt.title("Distribución en histograma de precios")
plt.show()
# Out:
#    ID NOMBRE_VEHICULO    PRECIO PLACAS_NUMERICAS  VENTAS_VEHICULO  \
# 0   1      Vehiculo_1  18951.42         9611-XYZ               60
# 1   2      Vehiculo_2  44940.96         3515-RTY               62
# 2   3      Vehiculo_3   6421.94         6478-FGH               62
# 3   4      Vehiculo_4  39959.05         7891-XYZ               22
# 4   5      Vehiculo_5  40716.90         7587-FGH               91
#
#    VEHICULOS_EXISTENCIA
# 0                    44
# 1                    39
# 2                     5
# 3                    43
# 4                    17
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    700 non-null    int64
#  1   NOMBRE_VEHICULO       700 non-null    object
#  2   PRECIO                700 non-null    float64
#  3   PLACAS_NUMERICAS      700 non-null    object
# ...

# %% [markdown]
# Ejercicio 2

# %%
import pandas as pd
import numpy as np

info = pd.read_csv(r"videojuegos_nan_duplicates.csv")
pd.set_option('display.max_rows', None)

# --- Descripción de Contenido ---
print(info.describe())
print(info.info())

# --- Mostrar información ---
print(info.head())
print(info.shape)
print(info.dtypes)

# --- Análisis y limpieza de datos ---

# 1. Ver dónde hay nulos (True/False)
print(info.isnull())

# 2. Sumar cuántos nulos hay por columna (Muy útil para exámenes)
print(info.isnull().sum())

# 3. Guardar booleanos de nulos (CORREGIDO)
infonulos = info.isna() 
print(infonulos)

# 4. Ver los que NO son nulos
infonotnull = info.notnull()
print(infonotnull)

# 5. Rellenar nulos con un valor específico
infofillna = info.fillna(777)
print(infofillna)

#---- Eliminación de Duplicados ----
info.dropna(axis = 0)

info.drop_duplicates()

#---- Filtrado de datos ----
print(info.iloc[3])
print(info.iloc[0:5, 0:3])

print(info.loc[10])
print(info.loc[:, ["id", "title", "genre",	"platform",	"release_year",	"decade", "rating",	"sales_millions", "genre_copy",	"rating_copy"]])
print(info.loc[info["rating"]>16])
# Out:
#                id  release_year      rating  sales_millions  rating_copy
# count  474.000000    464.000000  474.000000      477.000000   474.000000
# mean   246.493671   2000.247845    5.519409        9.716059     5.519409
# std    143.421277     11.833848    2.512994        5.765044     2.512994
# min      1.000000   1980.000000    1.100000        0.140000     1.100000
# 25%    122.250000   1990.000000    3.400000        4.840000     3.400000
# 50%    245.500000   2000.500000    5.500000        9.380000     5.500000
# 75%    367.750000   2011.000000    7.700000       14.830000     7.700000
# max    500.000000   2019.000000   10.000000       19.980000    10.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 520 entries, 0 to 519
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              474 non-null    float64
#  1   title           466 non-null    object
# ...
